# %% [markdown]
# # *Multivariate regression*

# %%
import pandas as pd

# %%
student = pd.read_csv("./DataSets/student.csv")
student.head()
# Out:
#    Math  Reading  Writing
# 0    48       68       63
# 1    62       81       72
# 2    79       80       78
# 3    76       83       79
# 4    59       64       62

# %%
len(student)
# Out:
# 1000

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from mpl_toolkits.mplot3d import Axes3D

# %%
X = student[["Math","Reading"]]
Y = student[["Writing"]]

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((800, 2), (200, 2), (800, 1), (200, 1))

# %%
reg = LinearRegression()

model = reg.fit(X_train,Y_train)

# %%
y_pred = model.predict(X_test)

# %%
model.coef_
# Out:
# array([[0.09356445, 0.91854045]])

# %%
model.intercept_
# Out:
# array([-1.9502733])

# %%
import numpy as np
np.sqrt(mean_squared_error(Y_test,y_pred))
# Out:
# 4.414674861496005

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.9052409628220129

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Resudal Plot

# %%
#resudual plot
plt.scatter(y_pred, ( Y_test - y_pred ), color='red')
plt.hlines(y=0, xmin= -10, xmax=100,linewidth=5,color="g")

plt.title('Residual plot')
plt.show()

# %% [markdown]
# # 3 Dimensional Plot

# %%
fig =plt.figure()
ax = Axes3D(fig)
ax.scatter(student.Math.values, student.Reading.values, student.Writing.values,color="purple")
plt.show()
